# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv('../../data/tidy/govt_measures.csv')
df = df[['ISO','CATEGORY','ENTRY_DATE']]
df.ENTRY_DATE = pd.to_datetime(df.ENTRY_DATE)
df.head()
#df.CATEGORY.str.replace('Public health measures', 'PH', regex=False)
# PH = public health
# SE = govt and socio-economic
# SD = social distancing
# MR = movement restrictions
# LD = lockdown
# HE = humanitarian exemption
# Out:
#    ISO                                CATEGORY ENTRY_DATE
# 0  AFG                  Public health measures 2020-03-14
# 1  AFG                  Public health measures 2020-03-14
# 2  AFG                  Public health measures 2020-03-14
# 3  AFG  Governance and socio-economic measures 2020-03-14
# 4  AFG                       Social distancing 2020-03-14

# %%
start_date = dt.datetime(2020,2,1) #.datetime.now().date())
date_range = pd.date_range(start_date, periods=213, freq='D')
idf = pd.DataFrame(
    data=0,
    index=pd.MultiIndex.from_product([df.CATEGORY.unique(), df.ISO.unique()]), #later, maybe: ['PH','SE','MR','LD','HE'] instead of actual category names
    columns=date_range
)
idf.head()
# Out:
#                             2020-02-01  2020-02-02  2020-02-03  2020-02-04  \
# Public health measures AFG           0           0           0           0
#                        ALB           0           0           0           0
#                        DZA           0           0           0           0
#                        AGO           0           0           0           0
#                        ATG           0           0           0           0
#
#                             2020-02-05  2020-02-06  2020-02-07  2020-02-08  \
# Public health measures AFG           0           0           0           0
#                        ALB           0           0           0           0
#                        DZA           0           0           0           0
#                        AGO           0           0           0           0
#                        ATG           0           0           0           0
#
# ...

# %%
for i in df.index:
    mdate = df.loc[i].ENTRY_DATE
    if (mdate > dt.datetime(2020,1,31)) & (mdate <= dt.datetime(2020, 8, 31)):
        idf.loc[(df.loc[i].CATEGORY, df.loc[i].ISO),df.loc[i].ENTRY_DATE] = 1

# %%
idf.loc[('Public health measures','AFG'),'2020-03-14']
# Out:
# 1

# %%
idf.head()
# Out:
#                             2020-02-01  2020-02-02  2020-02-03  2020-02-04  \
# Public health measures AFG           0           0           0           0
#                        ALB           0           0           0           0
#                        DZA           0           0           0           0
#                        AGO           0           0           0           0
#                        ATG           0           0           0           0
#
#                             2020-02-05  2020-02-06  2020-02-07  2020-02-08  \
# Public health measures AFG           0           0           0           0
#                        ALB           0           0           0           0
#                        DZA           0           0           0           0
#                        AGO           0           1           0           0
#                        ATG           0           0           0           0
#
# ...

# %%
# Examples
idf.loc['Governance and socio-economic measures'].head()
# Out:
#      2020-02-01  2020-02-02  2020-02-03  2020-02-04  2020-02-05  2020-02-06  \
# AFG           0           0           0           0           0           0
# ALB           0           0           0           0           0           0
# DZA           0           0           0           0           0           0
# AGO           0           0           0           0           0           1
# ATG           0           0           0           0           0           0
#
#      2020-02-07  2020-02-08  2020-02-09  2020-02-10  ...  2020-08-22  \
# AFG           0           0           0           0  ...           0
# ALB           0           0           0           0  ...           0
# DZA           0           0           0           0  ...           0
# AGO           0           0           0           0  ...           0
# ATG           0           0           0           0  ...           0
#
#      2020-08-23  2020-08-24  2020-08-25  2020-08-26  2020-08-27  2020-08-28  \
# ...
